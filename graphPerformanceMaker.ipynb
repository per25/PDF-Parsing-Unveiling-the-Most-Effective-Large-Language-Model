# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
performance_file_path = 'performance_metrics.xlsx'
performance_data = pd.read_excel(performance_file_path, header=0)

# %%
print(performance_data.columns)
# Out:
# Index(['Tool', 'File', 'Execution Time (seconds)', 'CPU Usage (percent)',
#        'Memory Usage (MB)', 'llm_tokens', 'embedding_tokens', 'pages_calls'],
#       dtype='object')

# %%
# Calculate the average correctness for each file
grouped_data = performance_data.groupby('Tool')['Execution Time (seconds)'].mean()

# Plotting the average correctness for each file
plt.figure(figsize=(10, 5))
bars = plt.bar(grouped_data.index, grouped_data, color='skyblue')
# plt.title('Average Correctness per Parsing Tool')
plt.xlabel('Parsing Tools')
plt.ylabel('Average Execution Time (seconds)')
plt.xticks(rotation=45)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)

# Annotating each bar within the bar, slightly below the top for visibility
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval - 3,  # Adjust the vertical position inside the bar
             f'{int(round(yval))}', ha='center', va='top', color='black')  # Change the text color to white for visibility

# Adding grid lines to the background for better readability
plt.grid(True, which='both', linestyle='-', linewidth=0.5, color='gray', axis='y')  # Grid lines along the y-axis

plt.tight_layout()

# Saving the plot as a PDF file
plt.savefig('average_executiontime_per_tool.pdf', format='pdf')

plt.show()

# %%
# Calculate the average correctness for each file
grouped_data = performance_data.groupby('File')['Execution Time (seconds)'].mean()

# Plotting the average correctness for each file
plt.figure(figsize=(10, 5))
bars = plt.bar(grouped_data.index, grouped_data, color='skyblue')
# plt.title('Average Correctness per Parsing Tool')
plt.xlabel('PDF Files')
plt.ylabel('Average Execution Time (seconds)')
plt.xticks(rotation=45)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)

# Annotating each bar within the bar, slightly below the top for visibility
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval - 3,  # Adjust the vertical position inside the bar
             f'{int(round(yval))}', ha='center', va='top', color='black')  # Change the text color to white for visibility

# Adding grid lines to the background for better readability
plt.grid(True, which='both', linestyle='-', linewidth=0.5, color='gray', axis='y')  # Grid lines along the y-axis

plt.tight_layout()

# Saving the plot as a PDF file
plt.savefig('average_executiontime_per_file.pdf', format='pdf')

plt.show()

# %%
# Calculate the average correctness for each file
grouped_data = performance_data.groupby('Tool')['Memory Usage (MB)'].mean()

# Plotting the average correctness for each file
plt.figure(figsize=(10, 5))
bars = plt.bar(grouped_data.index, grouped_data, color='skyblue')
# plt.title('Average Correctness per Parsing Tool')
plt.xlabel('Parsing Tools')
plt.ylabel('Average Memory Usage (MB)')
plt.xticks(rotation=45)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)

# Annotating each bar within the bar, slightly below the top for visibility
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval - 3,  # Adjust the vertical position inside the bar
             f'{int(round(yval))}', ha='center', va='top', color='black')  # Change the text color to white for visibility

# Adding grid lines to the background for better readability
plt.grid(True, which='both', linestyle='-', linewidth=0.5, color='gray', axis='y')  # Grid lines along the y-axis

plt.tight_layout()

# Saving the plot as a PDF file
plt.savefig('average_MemoryUsage_per_tool.pdf', format='pdf')

plt.show()

# %%
# Calculate the average correctness for each file
grouped_data = performance_data.groupby('File')['Memory Usage (MB)'].mean()

# Plotting the average correctness for each file
plt.figure(figsize=(10, 5))
bars = plt.bar(grouped_data.index, grouped_data, color='skyblue')
# plt.title('Average Correctness per Parsing Tool')
plt.xlabel('PDF Files')
plt.ylabel('Average Memory Usage (MB)')
plt.xticks(rotation=45)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)

# Annotating each bar within the bar, slightly below the top for visibility
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval - 3,  # Adjust the vertical position inside the bar
             f'{int(round(yval))}', ha='center', va='top', color='black')  # Change the text color to white for visibility

# Adding grid lines to the background for better readability
plt.grid(True, which='both', linestyle='-', linewidth=0.5, color='gray', axis='y')  # Grid lines along the y-axis

plt.tight_layout()

# Saving the plot as a PDF file
plt.savefig('average_MemoryUsage_per_file.pdf', format='pdf')

plt.show()

# %%
# Get the LLM tokens and calculate the cost for each tool

# 'llm_tokens', 'embedding_tokens', 'pages_calls'

grouped_data_onTokens = performance_data.groupby('Tool').agg({
    'llm_tokens': 'sum',
    'embedding_tokens': 'sum',
    'pages_calls': 'sum'
})

print(grouped_data_onTokens)

# Calculate the cost for each tool
# cost = llm_tokens || embedding_tokens || pages_calls * cost_per_token
# Out:
#                                                     llm_tokens  \
# Tool
# process_pdf_file_PDFMiner                                  0.0
# process_pdf_file_PDFMiner_as_HTML                          0.0
# process_pdf_file_PyMuPDF                                   0.0
# process_pdf_file_PyPDF                                     0.0
# process_pdf_file_UnstructuredPDF_OCR_only_strategy         0.0
# process_pdf_file_UnstructuredPDF_default_strategy          0.0
# process_pdf_file_UnstructuredPDF_hig_res_strategy          0.0
# process_pdf_file_llama_index_md                            0.0
# process_pdf_file_llama_index_txt                           0.0
# process_pdf_file_pdfminerSix                               0.0
# process_pdf_file_textract_with_correction             114278.0
#
#                                                     embedding_tokens  \
# Tool
# process_pdf_file_PDFMiner                                        0.0
# process_pdf_file_PDFMiner_as_HTML                                0.0
# process_pdf_file_PyMuPDF                                         0.0
# process_pdf_file_PyPDF                                           0.0
# process_pdf_file_UnstructuredPDF_OCR_only_strategy               0.0
# process_pdf_file_UnstructuredPDF_default_strategy                0.0
# process_pdf_file_UnstructuredPDF_hig_res_strategy                0.0
# process_pdf_file_llama_index_md                                  0.0
# process_pdf_file_llama_index_txt                                 0.0
# process_pdf_file_pdfminerSix                                     0.0
# process_pdf_file_textract_with_correction                    22059.0
#
#                                                     pages_calls
# Tool
# process_pdf_file_PDFMiner                                   0.0
# process_pdf_file_PDFMiner_as_HTML                           0.0
# process_pdf_file_PyMuPDF                                    0.0
# process_pdf_file_PyPDF                                      0.0
# process_pdf_file_UnstructuredPDF_OCR_only_strategy          0.0
# process_pdf_file_UnstructuredPDF_default_strategy           0.0
# process_pdf_file_UnstructuredPDF_hig_res_strategy           0.0
# process_pdf_file_llama_index_md                            23.0
# process_pdf_file_llama_index_txt                           23.0
# process_pdf_file_pdfminerSix                                0.0
# process_pdf_file_textract_with_correction                   0.0
